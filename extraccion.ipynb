# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Uso de API's
# -----------------------------------------------------------------------
import requests

# Para incluir una barra de proceso en for loops
# -----------------------------------------------------------------------
from tqdm import tqdm


# Para introducir tiempo entre las llamadas
# -----------------------------------------------------------------------
from time import sleep


# Para trabajar con archivos dotenv y los tokens
# -----------------------------------------------------------------------
import os
import dotenv
# dotenv.load_dotenv() ### reconoce un archivo .env y que tiene información

from time import sleep

# %%
import requests

url = "https://basketapi1.p.rapidapi.com/api/basketball/tournament/132/season/38191/standings/total"

headers = {
	"x-rapidapi-key": "8bf68f7481msh7aa93c8e8e9a6ffp19eef8jsn33f2cc37fe85",
	"x-rapidapi-host": "basketapi1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

responsa = response.json()

# %%
responsa.keys()
# Out:
# dict_keys(['standings'])

# %%
responsa['standings'][0]['']
# Out:
# {'tournament': {'name': 'NBA',
#   'slug': 'nba',
#   'category': {'name': 'USA',
#    'slug': 'usa',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'id': 15,
#    'flag': 'usa',
#    'alpha2': 'US'},
#   'uniqueTournament': {'name': 'NBA',
#    'slug': 'nba',
#    'primaryColorHex': '#045daf',
#    'secondaryColorHex': '#cc2b31',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'userCount': 261916,
#    'hasPerformanceGraphFeature': False,
#    'id': 132,
#    'displayInverseHomeAwayTeams': True},
#   'priority': 143,
#   'isGroup': False,
#   'isLive': False,
#   'id': 177},
#  'type': 'total',
#  'name': 'Eastern Conference',
#  'descriptions': [],
#  'tieBreakingRule': {'text': 'The League is sorted by percentage. In the event that two (or more) teams have the same record, they are placed in the same position',
#   'id': 217},
#  'rows': [{'team': {'name': 'Miami Heat',
#     'slug': 'miami-heat',
#     'shortName': 'Heat',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 69334,
#     'nameCode': 'MIA',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3435,
#     'teamColors': {'primary': '#98002e',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ميامي هيت',
#       'ru': 'Майами Хит'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Playoffs', 'id': 6},
#    'position': 1,
#    'matches': 82,
#    'wins': 53,
#    'scoresFor': 9022,
#    'scoresAgainst': 8657,
#    'percentage': 0.646,
#    'gamesBehind': 0,
#    'streak': -1,
#    'id': 694131,
#    'losses': 29,
#    'draws': 0,
#    'scoreDiffFormatted': '+365'},
#   {'team': {'name': 'Boston Celtics',
#     'slug': 'boston-celtics',
#     'shortName': 'Celtics',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 136147,
#     'nameCode': 'BOS',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3422,
#     'teamColors': {'primary': '#008348',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'بوسطن سيلتيكس',
#       'ru': 'Бостон Селтикс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Playoffs', 'id': 6},
#    'position': 2,
#    'matches': 82,
#    'wins': 51,
#    'scoresFor': 9164,
#    'scoresAgainst': 8567,
#    'percentage': 0.622,
#    'gamesBehind': 2,
#    'streak': 1,
#    'id': 694132,
#    'losses': 31,
#    'draws': 0,
#    'scoreDiffFormatted': '+597'},
#   {'team': {'name': 'Milwaukee Bucks',
#     'slug': 'milwaukee-bucks',
#     'shortName': 'Bucks',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 90475,
#     'nameCode': 'MIL',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3410,
#     'teamColors': {'primary': '#00471b',
#      'secondary': '#eee1c6',
#      'text': '#eee1c6'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ميلواكي باكس',
#       'ru': 'Милуоки Бакс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Playoffs', 'id': 6},
#    'position': 3,
#    'matches': 82,
#    'wins': 51,
#    'scoresFor': 9470,
#    'scoresAgainst': 9195,
#    'percentage': 0.622,
#    'gamesBehind': 2,
#    'streak': -1,
#    'id': 694133,
#    'losses': 31,
#    'draws': 0,
#    'scoreDiffFormatted': '+275'},
#   {'team': {'name': 'Philadelphia 76ers',
#     'slug': 'philadelphia-76ers',
#     'shortName': '76ers',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 56590,
#     'nameCode': 'PHI',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3420,
#     'teamColors': {'primary': '#006bb6',
#      'secondary': '#ed174c',
#      'text': '#ed174c'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'فيلاديلفيا  ERS 76',
#       'ru': 'Филадельфия  76ерс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Playoffs', 'id': 6},
#    'position': 4,
#    'matches': 82,
#    'wins': 51,
#    'scoresFor': 9015,
#    'scoresAgainst': 8801,
#    'percentage': 0.622,
#    'gamesBehind': 2,
#    'streak': 2,
#    'id': 694134,
#    'losses': 31,
#    'draws': 0,
#    'scoreDiffFormatted': '+214'},
#   {'team': {'name': 'Toronto Raptors',
#     'slug': 'toronto-raptors',
#     'shortName': 'Raptors',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 30456,
#     'nameCode': 'TOR',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3433,
#     'teamColors': {'primary': '#ce1141',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'تورونتو راپتورس',
#       'ru': 'Торонто Рапторс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Playoffs', 'id': 6},
#    'position': 5,
#    'matches': 82,
#    'wins': 48,
#    'scoresFor': 8970,
#    'scoresAgainst': 8782,
#    'percentage': 0.585,
#    'gamesBehind': 5,
#    'streak': -1,
#    'id': 694135,
#    'losses': 34,
#    'draws': 0,
#    'scoreDiffFormatted': '+188'},
#   {'team': {'name': 'Chicago Bulls',
#     'slug': 'chicago-bulls',
#     'shortName': 'Bulls',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 50071,
#     'nameCode': 'CHI',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3409,
#     'teamColors': {'primary': '#ce1141',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'شيكاغو بولس',
#       'ru': 'Чикаго Буллз'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Playoffs', 'id': 6},
#    'position': 6,
#    'matches': 82,
#    'wins': 46,
#    'scoresFor': 9152,
#    'scoresAgainst': 9184,
#    'percentage': 0.561,
#    'gamesBehind': 7,
#    'streak': 1,
#    'id': 694136,
#    'losses': 36,
#    'draws': 0,
#    'scoreDiffFormatted': '-32'},
#   {'team': {'name': 'Brooklyn Nets',
#     'slug': 'brooklyn-nets',
#     'shortName': 'Nets',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 41594,
#     'nameCode': 'BKN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3436,
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'بروكلين نيتس',
#       'ru': 'Бруклин Нетс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Qualification Playoffs', 'id': 14},
#    'position': 7,
#    'matches': 82,
#    'wins': 44,
#    'scoresFor': 9258,
#    'scoresAgainst': 9194,
#    'percentage': 0.537,
#    'gamesBehind': 9,
#    'streak': 4,
#    'id': 694137,
#    'losses': 38,
#    'draws': 0,
#    'scoreDiffFormatted': '+64'},
#   {'team': {'name': 'Atlanta Hawks',
#     'slug': 'atlanta-hawks',
#     'shortName': 'Hawks',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 31327,
#     'nameCode': 'ATL',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3423,
#     'teamColors': {'primary': '#e03a3e',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'اطلنطا هاوكس',
#       'ru': 'Атланта Хоукс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Qualification Playoffs', 'id': 14},
#    'position': 8,
#    'matches': 82,
#    'wins': 43,
#    'scoresFor': 9343,
#    'scoresAgainst': 9215,
#    'percentage': 0.524,
#    'gamesBehind': 10,
#    'streak': 1,
#    'id': 694139,
#    'losses': 39,
#    'draws': 0,
#    'scoreDiffFormatted': '+128'},
#   {'team': {'name': 'Cleveland Cavaliers',
#     'slug': 'cleveland-cavaliers',
#     'shortName': 'Cavaliers',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 39632,
#     'nameCode': 'CLE',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3432,
#     'teamColors': {'primary': '#871539',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'كليڢلاند كاڢالييرس',
#       'ru': 'Кливленд Кавальерс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Qualification Playoffs', 'id': 14},
#    'position': 9,
#    'matches': 82,
#    'wins': 44,
#    'scoresFor': 8839,
#    'scoresAgainst': 8665,
#    'percentage': 0.537,
#    'gamesBehind': 9,
#    'streak': 1,
#    'id': 694138,
#    'losses': 38,
#    'draws': 0,
#    'scoreDiffFormatted': '+174'},
#   {'team': {'name': 'Charlotte Hornets',
#     'slug': 'charlotte-hornets',
#     'shortName': 'Hornets',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 22903,
#     'nameCode': 'CHA',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3430,
#     'teamColors': {'primary': '#008ca8',
#      'secondary': '#1d1160',
#      'text': '#1d1160'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'تشارلوت هورنيتس',
#       'ru': 'Шарлотт Хорнетс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'promotion': {'text': 'Qualification Playoffs', 'id': 14},
#    'position': 10,
#    'matches': 82,
#    'wins': 43,
#    'scoresFor': 9457,
#    'scoresAgainst': 9421,
#    'percentage': 0.524,
#    'gamesBehind': 10,
#    'streak': 3,
#    'id': 694140,
#    'losses': 39,
#    'draws': 0,
#    'scoreDiffFormatted': '+36'},
#   {'team': {'name': 'New York Knicks',
#     'slug': 'new-york-knicks',
#     'shortName': 'Knicks',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 42236,
#     'nameCode': 'NYK',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3421,
#     'teamColors': {'primary': '#006bb6',
#      'secondary': '#f58426',
#      'text': '#f58426'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'نيويورك نيكس',
#       'ru': 'Нью-Йорк Никс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'position': 11,
#    'matches': 82,
#    'wins': 37,
#    'scoresFor': 8731,
#    'scoresAgainst': 8741,
#    'percentage': 0.451,
#    'gamesBehind': 16,
#    'streak': 2,
#    'id': 694141,
#    'losses': 45,
#    'draws': 0,
#    'scoreDiffFormatted': '-10'},
#   {'team': {'name': 'Washington Wizards',
#     'slug': 'washington-wizards',
#     'shortName': 'Wizards',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 19568,
#     'nameCode': 'WAS',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3431,
#     'teamColors': {'primary': '#f5002f',
#      'secondary': '#002566',
#      'text': '#002566'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'واشنطن ويزاردس',
#       'ru': 'Вашингтон Визардз'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'position': 12,
#    'matches': 82,
#    'wins': 35,
#    'scoresFor': 8907,
#    'scoresAgainst': 9184,
#    'percentage': 0.427,
#    'gamesBehind': 18,
#    'streak': -3,
#    'id': 694142,
#    'losses': 47,
#    'draws': 0,
#    'scoreDiffFormatted': '-277'},
#   {'team': {'name': 'Indiana Pacers',
#     'slug': 'indiana-pacers',
#     'shortName': 'Pacers',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 35494,
#     'nameCode': 'IND',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3419,
#     'teamColors': {'primary': '#00275d',
#      'secondary': '#ffc633',
#      'text': '#ffc633'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'اينديانا پايسيرس',
#       'ru': 'Индиана Пэйсерс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'position': 13,
#    'matches': 82,
#    'wins': 25,
#    'scoresFor': 9140,
#    'scoresAgainst': 9425,
#    'percentage': 0.305,
#    'gamesBehind': 28,
#    'streak': -10,
#    'id': 694143,
#    'losses': 57,
#    'draws': 0,
#    'scoreDiffFormatted': '-285'},
#   {'team': {'name': 'Detroit Pistons',
#     'slug': 'detroit-pistons',
#     'shortName': 'Pistons',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 19424,
#     'nameCode': 'DET',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3424,
#     'teamColors': {'primary': '#006bb6',
#      'secondary': '#ed174c',
#      'text': '#ed174c'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'ديترويت پيستونس',
#       'ru': 'Детройт Пистонс'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'position': 14,
#    'matches': 82,
#    'wins': 23,
#    'scoresFor': 8596,
#    'scoresAgainst': 9229,
#    'percentage': 0.28,
#    'gamesBehind': 30,
#    'streak': -3,
#    'id': 694144,
#    'losses': 59,
#    'draws': 0,
#    'scoreDiffFormatted': '-633'},
#   {'team': {'name': 'Orlando Magic',
#     'slug': 'orlando-magic',
#     'shortName': 'Magic',
#     'gender': 'M',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'userCount': 25607,
#     'nameCode': 'ORL',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'id': 3437,
#     'teamColors': {'primary': '#007dc5',
#      'secondary': '#c4ced3',
#      'text': '#c4ced3'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'اورلاندو ماجيك',
#       'ru': 'Орландо Мэджик'},
#      'shortNameTranslation': {}}},
#    'descriptions': [],
#    'position': 15,
#    'matches': 82,
#    'wins': 22,
#    'scoresFor': 8547,
#    'scoresAgainst': 9203,
#    'percentage': 0.268,
#    'gamesBehind': 31,
#    'streak': 1,
#    'id': 694145,
#    'losses': 60,
#    'draws': 0,
#    'scoreDiffFormatted': '-656'}],
#  'id': 85856,
#  'updatedAtTimestamp': 1649847305}
